# %% [markdown]
# # Oppgåver - Plotting og matematiske funksjonar
#
# Hugs å lasta biblioteka som me bruker i starten, og bruk førelesingsnotata som døme.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Oppgåve 1
#
# Me skal analysera denne funksjon:
# $$f(x) = x^5 - 3x^4 + 2x.$$
#
# **Oppgåve.**
# Plott funksjonen.
# Tilpass aksane og definisjonsområdet slik at formen på funksjonen vert tydleg.

# %% [markdown]
# ## Oppgåve 2

# %% [markdown]
# Me skal analysera éin av desse to funksjonane (eller båe dersom du har tid).
# 1. $f(x) = \sin (x+1)\pi$
# 1. $f(x) = \ln (2x+1)$

# %% [markdown]
# **Hint**
# Dersom du vil prøva noko meir avansert enn polynomfunksjonane, so finn du trigonometriske funksjonar og
# logatimar i numpy-biblioteket.  T.d.

# %%
import numpy as np
print( np.sin(3.14) )
print( np.log(2.7) )
# Out:
# 0.0015926529164868282
# 0.9932517730102834

# %% [markdown]
# Merk at `np.log` er den naturlege logaritmen.  Der finst òg `np.log2` og `np.log10`.

# %% [markdown]
# **Oppgåve.**
# Plott funksjonen.
# Tilpass aksane og definisjonsområdet slik at formen på funksjonen vert tydleg.
