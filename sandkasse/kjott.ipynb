# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv("handelkjottfrukt.csv", encoding="ISO-8859-1", sep="\t")
display(df)
df = df.melt(id_vars=["næring (SN2007)", "statistikkvariabel"], var_name="År", value_name="omsetning1")
display(df)
df = df.pivot(index="År", columns=["næring (SN2007)"], values="omsetning1")
df
# Out:
#   statistikkvariabel                              næring (SN2007)  ...   2023   2024
# 0          Omsetning  46.310 Engroshandel med frukt og grønnsaker  ...  32636  20885
# 1          Omsetning  46.320 Engroshandel med kjøtt og kjøttvarer  ...   2312   1294
#
# [2 rows x 19 columns]
#                                 næring (SN2007)  ... omsetning1
# 0   46.310 Engroshandel med frukt og grønnsaker  ...          0
# 1   46.320 Engroshandel med kjøtt og kjøttvarer  ...          0
# 2   46.310 Engroshandel med frukt og grønnsaker  ...          0
# 3   46.320 Engroshandel med kjøtt og kjøttvarer  ...          0
# 4   46.310 Engroshandel med frukt og grønnsaker  ...          0
# 5   46.320 Engroshandel med kjøtt og kjøttvarer  ...          0
# 6   46.310 Engroshandel med frukt og grønnsaker  ...          0
# 7   46.320 Engroshandel med kjøtt og kjøttvarer  ...          0
# 8   46.310 Engroshandel med frukt og grønnsaker  ...          0
# ...

# %%
data = {
    'Date': ['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-02', '2023-01-03', '2023-01-03'],
    'Store': ['Store A', 'Store B', 'Store A', 'Store B', 'Store A', 'Store B'],
    'Product': ['Apples', 'Apples', 'Oranges', 'Oranges', 'Apples', 'Apples'],
    'Sales': [100, 150, 120, 130, 110, 140],
    'Revenue': [200, 300, 240, 260, 220, 280]
}

df = pd.DataFrame(data)
df.pivot(index=["Date", "Store"], columns="Product", values=["Sales", "Revenue"])
# Out:
#                     Sales         Revenue
# Product            Apples Oranges  Apples Oranges
# Date       Store
# 2023-01-01 Store A  100.0     NaN   200.0     NaN
#            Store B  150.0     NaN   300.0     NaN
# 2023-01-02 Store A    NaN   120.0     NaN   240.0
#            Store B    NaN   130.0     NaN   260.0
# 2023-01-03 Store A  110.0     NaN   220.0     NaN
#            Store B  140.0     NaN   280.0     NaN
