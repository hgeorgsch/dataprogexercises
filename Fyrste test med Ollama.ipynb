# %%
# %pip install jupyter_ai_magics
# %pip install langchain-ollama
# %load_ext jupyter_ai_magics
# Out:
# Requirement already satisfied: jupyter_ai_magics in /home/georg/etc/pythonenv/lib/python3.11/site-packages (2.31.4)
# Requirement already satisfied: click<9,>=8.1.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from jupyter_ai_magics) (8.1.8)
# Requirement already satisfied: importlib-metadata>=5.2.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from jupyter_ai_magics) (8.7.0)
# Requirement already satisfied: ipython in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from jupyter_ai_magics) (8.16.1)
# Requirement already satisfied: jsonpath-ng<2,>=1.5.3 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from jupyter_ai_magics) (1.7.0)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from jupyter_ai_magics) (0.3.23)
# Requirement already satisfied: langchain<0.4.0,>=0.3.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from jupyter_ai_magics) (0.3.25)
# Requirement already satisfied: pydantic<3,>=2.10.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from jupyter_ai_magics) (2.11.4)
# Requirement already satisfied: zipp>=3.20 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from importlib-metadata>=5.2.0->jupyter_ai_magics) (3.21.0)
# Requirement already satisfied: ply in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from jsonpath-ng<2,>=1.5.3->jupyter_ai_magics) (3.11)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (0.3.59)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (0.3.42)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (2.31.0)
# Requirement already satisfied: PyYAML>=5.3 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (6.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.0->jupyter_ai_magics) (3.11.18)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.0->jupyter_ai_magics) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.0->jupyter_ai_magics) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.0->jupyter_ai_magics) (2.9.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.0->jupyter_ai_magics) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.0->jupyter_ai_magics) (2.2.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from pydantic<3,>=2.10.0->jupyter_ai_magics) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from pydantic<3,>=2.10.0->jupyter_ai_magics) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from pydantic<3,>=2.10.0->jupyter_ai_magics) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from pydantic<3,>=2.10.0->jupyter_ai_magics) (0.4.0)
# Requirement already satisfied: backcall in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from ipython->jupyter_ai_magics) (0.2.0)
# Requirement already satisfied: decorator in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from ipython->jupyter_ai_magics) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from ipython->jupyter_ai_magics) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from ipython->jupyter_ai_magics) (0.1.6)
# Requirement already satisfied: pickleshare in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from ipython->jupyter_ai_magics) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from ipython->jupyter_ai_magics) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from ipython->jupyter_ai_magics) (2.16.1)
# Requirement already satisfied: stack-data in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from ipython->jupyter_ai_magics) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from ipython->jupyter_ai_magics) (5.12.0)
# Requirement already satisfied: pexpect>4.3 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from ipython->jupyter_ai_magics) (4.8.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->jupyter_ai_magics) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->jupyter_ai_magics) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->jupyter_ai_magics) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->jupyter_ai_magics) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->jupyter_ai_magics) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->jupyter_ai_magics) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->jupyter_ai_magics) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->jupyter_ai_magics) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->jupyter_ai_magics) (0.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from jedi>=0.16->ipython->jupyter_ai_magics) (0.8.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.58->langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.58->langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (23.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (0.23.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from pexpect>4.3->ipython->jupyter_ai_magics) (0.7.0)
# Requirement already satisfied: wcwidth in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->jupyter_ai_magics) (0.2.8)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->jupyter_ai_magics) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from requests<3,>=2->langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from requests<3,>=2->langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from requests<3,>=2->langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from requests<3,>=2->langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (2023.7.22)
# Requirement already satisfied: greenlet>=1 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (3.2.1)
# Requirement already satisfied: executing>=1.2.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from stack-data->ipython->jupyter_ai_magics) (2.0.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from stack-data->ipython->jupyter_ai_magics) (2.4.1)
# Requirement already satisfied: pure-eval in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from stack-data->ipython->jupyter_ai_magics) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from asttokens>=2.1.0->stack-data->ipython->jupyter_ai_magics) (1.16.0)
# Requirement already satisfied: anyio in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->jupyter_ai_magics) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.0->jupyter_ai_magics) (1.3.1)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain-ollama in /home/georg/etc/pythonenv/lib/python3.11/site-packages (0.3.2)
# Requirement already satisfied: ollama<1,>=0.4.4 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain-ollama) (0.4.8)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.52 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain-ollama) (0.3.59)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-ollama) (0.3.42)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-ollama) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-ollama) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-ollama) (6.0)
# Requirement already satisfied: packaging<25,>=23.2 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-ollama) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-ollama) (4.13.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-ollama) (2.11.4)
# Requirement already satisfied: httpx<0.29,>=0.27 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from ollama<1,>=0.4.4->langchain-ollama) (0.28.1)
# Requirement already satisfied: anyio in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (4.9.0)
# Requirement already satisfied: certifi in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (1.0.7)
# Requirement already satisfied: idna in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (2.31.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (3.3.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (1.26.18)
# Requirement already satisfied: sniffio>=1.1 in /home/georg/etc/pythonenv/lib/python3.11/site-packages (from anyio->httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (1.3.1)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# The jupyter_ai_magics extension is already loaded. To reload it, use:
#   %reload_ext jupyter_ai_magics

# %%
# %%ai ollama:deepseek-coder-v2
# Write a poem about a beginner programming in python
# Out:
#  ```markdown
# # Beginner's Blossoms
#
# In the garden where code does bloom,
# A novice planted seeds of Python's home.
#
# With fingers nimble and eager to learn,
# They typed their first lines with gentle wend.
#
# "Hello, world!" softly spoken aloud,
# The console greeted back with a kind word.
#
# Variables grew from the seed they had sown,
# Strings blossomed, integers now showed their glow.
#
# Loops and conditions began to take root,
# Their logic deep within the soil took root.
#
# ```python
# for i in range(10):
#     print(i)
# ```
#
# Each line crafted with care, each error unmasked by trial and strife.
#
# Conditional logic now understood too:
# ```if __name__ == "__main__": pass```
#
# Lists and dictionaries formed a garden so grand,
# Their structure now clear as the sun in the sky when it starts to plan.
#
# With every line of code that they wrote,
# A story began to unfold before their very eyes.
#
# The console responded with feedback bright and true,
# In Python's world, a novice had indeed grew.
#
# Through loops and conditions deep and wide,
# Their skills evolved, just like the flowers in the sky.
#
# So here's to the beginner, who ventured out alone,
# With dreams of coding grand, their future now securely grown.
# ```
# ```markdown
# ```

# %%
# %ai list
# Out:
# ai21
# Requires environment variable: AI21_API_KEY (not set)
# * ai21:j1-large
# * ai21:j1-grande
# * ai21:j1-jumbo
# * ai21:j1-grande-instruct
# * ai21:j2-large
# * ai21:j2-grande
# * ai21:j2-jumbo
# * ai21:j2-grande-instruct
# * ai21:j2-jumbo-instruct
#
# gpt4all
# * gpt4all:ggml-gpt4all-j-v1.2-jazzy
# * gpt4all:ggml-gpt4all-j-v1.3-groovy
# * gpt4all:ggml-gpt4all-l13b-snoozy
# * gpt4all:mistral-7b-openorca.Q4_0
# * gpt4all:mistral-7b-instruct-v0.1.Q4_0
# * gpt4all:gpt4all-falcon-q4_0
# * gpt4all:wizardlm-13b-v1.2.Q4_0
# * gpt4all:nous-hermes-llama2-13b.Q4_0
# * gpt4all:gpt4all-13b-snoozy-q4_0
# * gpt4all:mpt-7b-chat-merges-q4_0
# * gpt4all:orca-mini-3b-gguf2-q4_0
# * gpt4all:starcoder-q4_0
# * gpt4all:rift-coder-v0-7b-q4_0
# * gpt4all:em_german_mistral_v01.Q4_0
#
# huggingface_hub
# Requires environment variable: HUGGINGFACEHUB_API_TOKEN (not set)
# * See [https://huggingface.co/models](https://huggingface.co/models) for a list of models. Pass a model's repository ID as the model ID; for example, `huggingface_hub:ExampleOwner/example-model`.
#
# ollama
# * See [https://www.ollama.com/library](https://www.ollama.com/library) for a list of models. Pass a model's name; for example, `deepseek-coder-v2`.
#
# qianfan
# Requires environment variables: QIANFAN_AK (not set), QIANFAN_SK (not set)
# * qianfan:ERNIE-Bot
# * qianfan:ERNIE-Bot-4
#
# togetherai
# Requires environment variable: TOGETHER_API_KEY (not set)
# * togetherai:Austism/chronos-hermes-13b
# * togetherai:DiscoResearch/DiscoLM-mixtral-8x7b-v2
# * togetherai:EleutherAI/llemma_7b
# * togetherai:Gryphe/MythoMax-L2-13b
# * togetherai:Meta-Llama/Llama-Guard-7b
# * togetherai:Nexusflow/NexusRaven-V2-13B
# * togetherai:NousResearch/Nous-Capybara-7B-V1p9
# * togetherai:NousResearch/Nous-Hermes-2-Yi-34B
# * togetherai:NousResearch/Nous-Hermes-Llama2-13b
# * togetherai:NousResearch/Nous-Hermes-Llama2-70b
#
#
# Aliases and custom commands:
# gpt2 - huggingface_hub:gpt2
# gpt3 - openai:davinci-002
# chatgpt - openai-chat:gpt-3.5-turbo
# gpt4 - openai-chat:gpt-4
# ernie-bot - qianfan:ERNIE-Bot
# ernie-bot-4 - qianfan:ERNIE-Bot-4
# titan - bedrock:amazon.titan-tg1-large
# openrouter-claude - openrouter:anthropic/claude-3.5-sonnet:beta

# %%
# %%ai ollama:deepseek-coder-v2
# Please explain the code below
# --
# def hw():
#     print("Hello World")
# Out:
#  Sure! Let's break down the Python code snippet line by line and understand what it does, while providing an explanation in Markdown format.
#
# ```python
# def hw():
#     print("Hello World")
# ```
#
# This is a simple function definition written in Python. Here's a breakdown of each part:
#
# ### 1. `def` Keyword
# The `def` keyword is used to define a function in Python. It stands for "define."
#
# ### 2. Function Name
# - **Function Name:** `hw`
#   - The name of the function is `hw`. By convention, functions often have names that are short and descriptive of their purpose. In this case, "hw" could stand for "Hello World," which is a common introductory message in programming tutorials.
#
# ### 3. Parentheses
# - **Parentheses:** `()`
#   - The parentheses following the function name indicate that this is a function without any parameters (also known as arguments). Parameters are placeholders for values that can be passed to the function when it is called. Since we don't need to pass any values, the parentheses remain empty.
#
# ### 4. Colon (`:`)
# - **Colon:** `:`
#   - The colon indicates the start of the function body. Everything inside the function (indented) belongs to the function and will be executed when the function is called.
#
# ### 5. Indentation
# - **Indentation:** Four spaces or one tab before the `print` statement.
#   - In Python, indentation is used to define the scope of loops, functions, and other blocks of code. All lines within the function must be indented at the same level. This example uses four spaces for indentation.
#
# ### 6. `print("Hello World")`
# - **Print Statement:** `print("Hello World")`
#   - The `print` statement is used to output text or variables to the console (or terminal). Here, it outputs the string "Hello World".
#
# When you run this code, the function `hw()` will be defined and can be called later in your program. When you call `hw()`, it will execute the `print("Hello World")` statement, resulting in the output:
#
# ```markdown
# # Function Definition
#
# In the garden where code does bloom,
# A developer planted seeds of Python's home.
#
# They defined a function with precision and care,
# ```def hw(): print("Hello World")```
#
# With fingers nimble and eager to share,
# They called upon the function they had just made clear.
#
# ```hw()```
# The console greeted back with delight: "Hello World!"
#
# Variables blossomed like flowers in spring rain,
# Strings and integers now proudly displayed their gain.
#
# Loops and conditions danced in a playful way,
# Their logic deep within the soil took root each day.
#
# Conditional logic now understood too:
# ```if __name__ == "__main__": pass```
#
# Lists and dictionaries formed a garden so grand,
# Their structure now clear as the sun in the sky when it starts to plan.
#
# With every line of code that they wrote,
# A story began to unfold before their very eyes.
#
# The console responded with feedback bright and true,
# In Python's world, a developer had indeed grew.
#
# Through loops and conditions deep and wide,
# Their skills evolved, just like the flowers in the sky.
#
# So here's to the developer, who ventured out alone,
# With dreams of coding grand, their future now securely grown.
# ```

# %%
# %%ai ollama:deepseek-coder-v2
# Please explain the code below
# --
# print( "Hello World!" )
# Out:
#  Sure! The provided code snippet is a simple Python script that prints "Hello World!" to the console. Here's an explanation of how it works, formatted in Markdown:
#
# ```python
# print("Hello World!")
# ```
#
# ### Explanation
#
# 1. **`print` Function**:
#    - `print` is a built-in function in Python used to display text or the value of variables on the console (or terminal).
#
# 2. **String inside Parentheses**:
#    - The string `"Hello World!"` is enclosed within parentheses (`()`). This string is what we want to be displayed when the script runs.
#
# 3. **Execution**:
#    - When you run this script, the output will be:
#      ```
#      Hello World!
#      ```
#    - This is because the `print` function takes the string inside the parentheses and outputs it to the console.
#
# ### Markdown Output
#
# ```markdown
# # Python Script Explanation
#
# In a world where code whispers secrets,
# A simple script came into being:
#
# ```python
# print("Hello World!")
# ```
#
# With just one line of command,
# The universe was greeted with a grand fanfare.
#
# When executed, this small script would say:
# "Hello World!" to the console display.
#
# Strings and functions combined in harmony,
# A new developer learned that day how scripting could inspire.
# ```
#
# This Markdown format provides a concise yet engaging explanation of the code's purpose and function within Python.
