# %% [markdown]
# # Hent kursinnhold
#
# * Plasser denne notebooken der hvor du vil hente inn mappen med kursinnholdet
# * Kjør cellen under for å hente inn kursinnholdet
# * *Merk: Du må ha innstallert git (åpne terminal og skriv inn «conda install anaconda::git»)*

# %%
# !git clone https://github.com/jonasjul/IIRA2001H24.git
# Out:
# Cloning into 'IIRA2001H24'...
# remote: Enumerating objects: 562, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 562 (delta 32), reused 53 (delta 15), pack-reused 490 (from 1)
# Receiving objects: 100% (562/562), 10.54 MiB | 27.90 MiB/s, done.
# Resolving deltas: 100% (278/278), done.
