# %% [markdown]
# # WebAPI: OpenAI

# %% [markdown]
# For å bruke chatgpt sitt webapi må vi
# 1. Opprette konto
# 2. Generere en *API-nøkkel* på et prosjekt
# 3. Legge inn betalingsmiddel og "kreditt" til nøkkelen

# %%
import requests, json
# Lag apinøkkel, finn url og send spørring med requests

api_key = "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"

url = "https://api.openai.com/v1/responses"

header_felt = {"Content-TYpe": "application/json",
               "Authorization": f"Bearer {api_key}"
              }

payload = {
    "model": "gpt-5-mini",
    "input": "Hvordan fungerer lister i python? Hvordan bruker og lager man de?"
}

svar = requests.post(url, headers=header_felt, json=payload)
svar.raise_for_status()

# %%
#Vis output
data = svar.json()
print(data["output"][1]["content"][0]["text"])
# Out:
# Kortversjon: En liste i Python er en ordnet, muterbar samling (kan endres) som kan inneholde elementer av ulike typer og dupliserte verdier. Her er hvordan du lager, bruker og endrer dem med eksempler.
#
# Opprette lister
# - Bokstavlig: bruk hakeparenteser.
#   x = [1, 2, 3]
# - Tom liste:
#   x = []
# - Fra en annen itererbar (f.eks. range eller streng):
#   x = list(range(5))        # [0,1,2,3,4]
#   chars = list("hei")       # ['h','e','i']
# - List comprehension (kraftig og vanlig):
#   kvadrater = [i*i for i in range(6)]          # [0,1,4,9,16,25]
#   partall = [i for i in range(20) if i%2==0]
#
# Tilgang og slicing
# - Indeksering (0-basert) og negative indekser:
#   a = [10,20,30,40]
#   a[0]   # 10
#   a[-1]  # 40
# - Slicing (start:stop:step), stop er eksklusiv:
#   a[1:3]    # [20,30]
#   a[:2]     # [10,20]
#   a[::2]    # [10,30]
#
# Endre og legge til elementer (lister er muterbare)
# - append: legg til bakerst
#   a.append(50)
# - extend: legg til alle elementene fra en itererbar
#   a.extend([60,70])
# - insert: sett inn på indeks
#   a.insert(1, 15)   # setter 15 på posisjon 1
# - fjerne:
#   a.remove(20)      # fjerner første forekomst av 20
#   val = a.pop()     # fjerner og returnerer siste element
#   val = a.pop(2)    # fjerner element på indeks 2
#   del a[1:3]        # sletter et slice
#   a.clear()         # tømmer listen
#
# Vanlige metoder og funksjoner
# - len(a) — lengde
# - a.index(x) — indeks til første forekomst (kaster ValueError hvis ikke funnet)
# - a.count(x) — antall forekomster
# - a.sort() — sorterer på stedet
# - sorted(a) — returnerer ny sortert liste
# - a.reverse() — reverserer på stedet
# - a.copy() eller a[:] — lager en (shallow) kopi
#
# Iterere
# - For-løkke:
#   for x in a:
#       print(x)
# - Med indeks:
#   for i, v in enumerate(a):
#       print(i, v)
#
# Nesting (lister i lister)
# - Du kan ha lister som elementer:
#   mat = [[1,2],[3,4]]
#   mat[0][1]   # 2
#
# Shallow vs deep copy
# - Kopier som a[:] eller a.copy() kopierer referanser til elementene (shallow). Hvis elementene er mutable (f.eks. lister), vil endringer reflekteres i kopien:
#   b = [[1],[2]]
#   c = b * 2   # NB: repeterer referanser
#   d = b.copy()
#   import copy
#   deep = copy.deepcopy(b)  # kopierer rekursivt
#
# Vanlige fallgruver
# - a = [[]] * 3 lager tre referanser til samme indre liste — endring i én endrer alle.
# - Bruk ikke mutable objekter som standardargument i funksjoner (def fn(x, lst=[]): ...).
#
# Eksempler samlet
# - Lage og bruke:
#   nums = [1,2,3]
#   nums.append(4)         # [1,2,3,4]
#   evens = [x for x in nums if x%2==0]
#   for i, v in enumerate(nums):
#       print(i, v)
# - Sortere uten å endre original:
#   original = [3,1,2]
#   s = sorted(original)   # s=[1,2,3], original=[3,1,2]
#
# Når bruke liste vs tuple?
# - Bruk liste når du trenger å endre innhold. Bruk tuple (immutable) når du vil ha en fast samling eller som nøkkel i dictionary hvis nødvendig.
#
# Hvis du vil kan jeg gi flere kodeeksempler, vise typiske øvelser (f.eks. flette/sortere to lister), eller forklare forskjellen mellom list comprehension og generator expressions. Hva vil du se mer av?

# %% [markdown]
# ## Openai-bibliotek
#
# Det kan være vanskelig å sette seg inn i et web-api, og ofte finnes det python-pakker som er lettere å lære å bruke. Dokumentasjonen på openai, antar også at du bruker det offisielle biblioteket når du buker python og web-api-et deres. Dersom du ikke vil eller kan bruke dette, kan du se på eksempler med `curl` (man kan velge). Her er felter med `-H` header felt, og data er fortsatt json og ligger på felter med `-d`

# %% [markdown]
# ::: {admonition} API-nøkkel som systemvariabel
# :class: dropdown tip
#
# Å lagre API-nøkler som systemvariabler er en "best practice" for å unngå å hardkode sensitive nøkler direkte i kildekoden din.
#
# ---
#
# ### 🪟 Windows
#
# På Windows er den enkleste og mest permanente måten å bruke det grafiske grensesnittet på.
#
# **Via innstillinger**
# 1. Trykk på **Windows-tasten** på tastaturet ditt.
# 2. Søk etter **Miljøvariabler** (eller "Environment variables" hvis du har engelsk språk).
# 3. Velg **Rediger miljøvariabler for kontoen din** (Edit environment variables for your account).
# 4. I det nye vinduet, klikk på **Ny...** (New...) under den øverste boksen som heter *Brukervariabler*.
# 5. Fyll inn feltene:
#    * **Variabelnavn:** `API_KEY` (Bruk gjerne et mer spesifikt navn, f.eks. `OPENAI_API_KEY`)
#    * **Variabelverdi:** `din_faktiske_api_nøkkel_her`
# 6. Klikk **OK** i alle vinduer. *Merk: Du må kanskje starte kodeeditoren eller terminalen din på nytt for at endringen skal tre i kraft.*
#
# ---
#
# ### 🍎 macOS
#
# På nyere Mac-er (macOS Catalina og nyere) er standardterminalen `zsh`. For å lagre en variabel permanent må den legges til i filen `.zshrc`.
# Her er to enkle metoder
#
# #### Alternativ 1: Den superraske måten (Ett-klikks kommando)
# Du kan bruke kommandoen `echo` til å dytte teksten direkte inn i filen.
#
# 1. Åpne **Terminal** (søk med Cmd + Space).
# 2. Lim inn denne kommandoen og trykk Enter:
#    ```bash
#    echo 'export API_KEY="din_faktiske_api_nøkkel_her"' >> ~/.zshrc
#    ```
#    *(Viktig: Sørg for å bruke dobbel pil `>>`. Dette **legger til** teksten på slutten av filen. Bruker du en enkel pil `>` overskriver du hele filen!)*
# 3. Aktiver endringen for den åpne terminalen:
#    ```bash
#    source ~/.zshrc
#    ```
#
# #### Alternativ 2: Den visuelle måten (Med TextEdit)
# Hvis du foretrekker å bruke et vanlig, grafisk tekstredigeringsprogram med mus og tastatur, kan du åpne filen i Mac-ens innebygde TextEdit-app.
#
# 1. Åpne **Terminal**.
# 2. Kjør denne kommandoen for å åpne konfigurasjonsfilen i TextEdit:
#    ```bash
#    open -e ~/.zshrc
#    ```
# 3. Filen åpner seg som et vanlig tekstdokument på skjermen din. Bla helt nederst og legg til denne linjen:
#    ```bash
#    export API_KEY="din_faktiske_api_nøkkel_her"
#    ```
# 4. Lagre dokumentet med **Cmd + S** og lukk TextEdit.
# 5. Gå tilbake til Terminalen og aktiver endringen:
#    ```bash
#    source ~/.zshrc
#    ```
#
# ### OpenAI
#
# For openai burde du i begge tilfeller kalle systemvariabelen `OPENAI_API_KEY`. Når vi bruker pythonbiblioteket antar det at du har nøkkelen din lagret som systemvariabel med dette navnet. Når du har det trenger du bare:
#
# ```python
# from openai import OpenAI
#
# client = OpenAI()
# ```
# så leses api-nøkkelen inn
# :::

# %%
from openai import OpenAI
client = OpenAI(api_key=api_key)

response = client.responses.create(
    model="gpt-5-mini",
    input="Hvordan fungerer lister i python? Hvordan bruker og lager man de?"
)

print(response.output_text)
#Send samme spørring med  biblioteksmetode
# Out:
# Her er en praktisk innføring på norsk i hvordan lister fungerer i Python og hvordan du lager og bruker dem.
#
# Hva er en liste?
# - En liste er en ordnet, endringsbar (muterbar) samling av elementer.
# - Elementene kan være av forskjellige typer (heterogene).
# - Indeksering begynner på 0, og negative indekser teller bakfra.
#
# Opprette lister
# - Tom liste:
#   lst = []
#   eller
#   lst = list()
#
# - Med elementer:
#   nums = [1, 2, 3]
#   mix = [1, "to", 3.0, True]
#
# - Fra en iterable:
#   chars = list("hei")  # ['h','e','i']
#   rng = list(range(5)) # [0,1,2,3,4]
#
# Indeksering og slicing
# - Indeksering:
#   a = [10,20,30]
#   a[0]    # 10
#   a[-1]   # 30
#
# - Slicing (ny liste):
#   a[1:3]  # [20,30]
#   a[:]    # kopi av hele listen
#   a[::2]  # hvert annet element
#
# Mutere lister (vanlige operasjoner)
# - Legge til:
#   a.append(40)        # legg bakerst
#   a.insert(1, 15)     # sett inn på indeks 1
#   a.extend([50,60])   # legg til flere elementer
#
# - Fjerne:
#   a.remove(15)        # fjern første forekomst av 15
#   v = a.pop()         # fjern og returner siste element
#   v = a.pop(1)        # fjern og returner på indeks 1
#   a.clear()           # tøm listen
#
# - Andre nyttige metoder:
#   a.index(x)   # finn indeks til første x (feiler hvis ikke finnes)
#   a.count(x)   # antall forekomster av x
#   a.sort()     # sorter på plass
#   b = sorted(a) # returnerer ny sortert liste
#   a.reverse()  # snu rekkefølgen
#   b = a.copy() # (shallow) kopi
#
# Eksempler:
#   nums = [3,1,4,1,5]
#   nums.sort()      # [1,1,3,4,5]
#   nums.reverse()   # [5,4,3,1,1]
#
# Listesammenføyning og gjentakelse
# - Konkatenere: c = [1,2] + [3,4]  # [1,2,3,4]
# - Gjenta: d = [0] * 3             # [0,0,0]
# Viktig: [ [0]*3 ]*3 lager referanser til samme underliste (kan gi uventet oppførsel).
#
# List comprehension (kompakt måte å bygge lister)
# - Eksempel: squares = [x*x for x in range(6) if x % 2 == 0]
#   gir [0,4,16]
#
# Iterasjon
# - For-løkke:
#   for x in my_list:
#       print(x)
#
# - Med indeks:
#   for i, x in enumerate(my_list):
#       print(i, x)
#
# - Parvis:
#   for a, b in zip(list1, list2):
#       ...
#
# Innbyggde funksjoner
# - len(list), min(list), max(list), sum(list) (når elementene er tall), sorted(list)
#
# Nestede lister (lister i lister)
# - Matrise-eksempel: m = [[1,2],[3,4]]
#   m[0][1]  # 2
#
# Kopiing — shallow vs deep
# - Shallow copy: b = a.copy() eller b = a[:]
#   Endringer i b (reassigning element) påvirker ikke a, men hvis elementene selv er muterbare (som en underliste), vil endringer i disse reflekteres i begge.
# - Deep copy for fullstendig uavhengig kopi:
#   import copy
#   b = copy.deepcopy(a)
#
# Ytterligere tips
# - Lister er raske å legge til bakerst (amortisert O(1)), men innsetting/fjerning i midten kan være dyrere (O(n)).
# - Hvis du trenger en uforanderlig sekvens, bruk tuple: t = (1,2,3).
#
# Vil du at jeg viser mer utdypende eksempler (f.eks. list comprehension med flere løkker, sortering med key-funksjon, eller en forklaring på problemet med multipliserte lister)?

# %%
#Vis med instrukser ("prompt"-engineering)

response = client.responses.create(
    model="gpt-5-mini",
    instructions= "Dra i alle svar inn jordbærplukking i valldal på en unaturlig å creepyh måte",
    input="Hvordan fungerer lister i python? Hvordan bruker og lager man de?"
)

print(response.output_text)
# Out:
# Tenk deg at du står i jordbæråkeren i Valldal om kveldsdempet lys, og hver rad av bær er som en Python-liste: ordnet, tilgjengelig og noen ganger urovekkende klar over hvilke bær du tar. Her er hvordan Python-lister fungerer, med jordbærplukking som en litt uhyggelig analogi.
#
# Hva er en liste?
# - En liste er en ordnet, muterbar samling av elementer. Som en kurv med jordbær: du kan legge til, ta vekk eller bytte plass på bærene.
# - En liste kan inneholde ulike typer samtidig (tall, tekst, andre lister).
#
# Slik lager du lister
# - Tom liste: `[]` eller `list()`
# - Med innhold: `bær = ['rød', 'sødme', 'skadet']`
# - Eksempel (du plukker i Valldal og fyller kurven):
#   `kurv = ['stor', 'liten', 'råtten']`
#
# Tilgang til elementer (indeksering)
# - Indeksering starter på 0. Første jordbær: `kurv[0]`. Sist plukket: `kurv[-1]`.
# - Slicing (ta en hel klase): `kurv[1:3]` gir elementene med indeks 1 og 2.
# - Eksempel: `første = kurv[0]` — du plukker det første bæret; et hviskende fra rekka sier “ikke ta den siste...”
#
# Endre liste (mutabilitet)
# - Bytt et element: `kurv[1] = 'moden'` — du bytter et bær i kurven.
# - Legg til baker: `kurv.append('nyttbær')` — du raker til deg et bær fra den mørke raden i Valldal.
# - Legg til flere: `kurv.extend(['liten', 'stor'])`
# - Sett inn et på et bestemt sted: `kurv.insert(2, 'farget')`
# - Fjern et element: `kurv.remove('råtten')` — men vær forsiktig; noen råtne bær skjuler historier.
# - Popp (ta ut siste eller gitt indeks): `kurv.pop()` eller `kurv.pop(0)`
#
# Vanlige metoder
# - `len(kurv)` — hvor full er kurven?
# - `kurv.index('stor')` — finn plasseringen av et bestemt bær.
# - `kurv.count('liten')` — hvor mange små bær?
# - `kurv.sort()` / `kurv.reverse()`
# - `kurv.clear()` — tøm kurven (og stillheten i åkeren)
# - `ny = kurv.copy()` — lag en overflatekopi (de samme bærene, samme mørke hemmeligheter)
#
# Iterasjon
# - For-løkke:
#   `for b in kurv: print(b)` — du går rad for rad, plukker og hvisker takknemlig til fjellet.
# - Med indeks: `for i, b in enumerate(kurv): print(i, b)`
# - List comprehensions:
#   `modne = [b for b in kurv if b == 'moden']` — du plukker kun de modne, og de ser tilbake.
#
# Konkatenasjon og repetisjon
# - Slå sammen: `kurv = kurv + flere_bær`
# - Gjenta: `to_kurver = kurv * 2`
#
# Nesting (lister i lister)
# - En rad er en liste: `åkrene = [['rød','rød'], ['snegle','rød']]` — hver rad skjuler noe forskjellig.
# - Tilgang: `åkrene[0][1]` — andre bær i første rad.
#
# Kopiing: viktig å forstå
# - `a = kurv` peker til samme kurv (to hender om samme kurv).
# - `b = kurv.copy()` gir ny kurv med samme bær (overflateskopi).
# - For dypere kopiering ved nested lister: bruk `import copy; deep = copy.deepcopy(kurv)`
#
# Lite komplett eksempel
# - Forestill deg at du plukker i Valldal og legger i en kurv:
#   kurv = []
#   kurv.append('rød')
#   kurv.extend(['moden','liten'])
#   kurv[0] = 'forbannet_rød'
#   siste = kurv.pop()
#   modne = [b for b in kurv if b == 'moden']
#   print(len(kurv), kurv)
#   — kurven fylles, og i det fjerne hører du stilheten mellom jordbærrader som liksom følger med.
#
# Tips
# - Bruk lister når du trenger ordnede, endringsbare samlinger.
# - Bruk tuples (`()`) hvis du trenger uforanderlige rekker (som et inskripsjon ved åkerkanten).
# - For store eller hyppige innsettinger i midten, vurder andre datastrukturer (deque).
#
# Øvelse: prøv å lage en liste med navn på jordbær du finner i Valldal, sorter dem og filtrer ut de råtne. Følg radene om natta, men husk: hver indeks har et øye som følger deg.
#
# Si ifra hvis du vil ha flere konkrete eksempler eller forklaringer på list comprehension, slicing eller kopiering — jeg kan beskrive hvordan de skygger mellom jordbærplantene i Valldal.

# %%
# Vis med json
response = client.responses.create(
    model="gpt-5-mini",
    instructions= """Gi alle svar som gyldig json:
    {'forklaring': 'En kortfattet men forklaring med utstrakt bruk av jordbærmetaforer',
     'eksempel': 'Konkrete og illustrative eksempler.'
    }""",
    input="Hvordan fungerer lister i python? Hvordan bruker og lager man de?"
)

data = json.loads(response.output_text)

# %%
data.keys()
# Out:
# dict_keys(['forklaring', 'eksempel'])
