# %% [markdown]
# # Oppsumering
# ## Variabler
# Vi er interesserte i å drive med databehandling. Til det trenger vi variabler. Variablene kan for eksempel være navnet på en kontoinnehaver, beløpet på kontoen, kundens alder og om kunden er en viktig kunde.
# Variablene vi bruker i Python kan være av flere typer:

# %% [markdown]
# - #### string
# Ofte kan vi trenge å lagre tekst. Til det bruker vi strenger, som skrives i enkle eller dobble anførselsetegn. For eksempel:

# %%
kontoinnehaver =
# Out:
#   Cell In[19], line 1
#     kontoinnehaver =
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# - #### float
# Til å lagre desimaltall bruker vi variabler av typen float. For eksempel:

# %%
saldo =

# %% [markdown]
# - #### int
# Til å lagre heltall bruker vi variabeltypen int. For eksempel:

# %%
alder =

# %% [markdown]
# - #### bool
# Til å lagre om noe er sant eller ikke bruker vi variabeltypen bool. Alternativene er True og False For eksempel:

# %%
viktig =

# %% [markdown]
# ## Funksjoner
# For å gjøre ting med variablene våre trenger vi funksjoner. Et eksempel på en innebygd funksjon er print().

# %%
print(kontoinnehaver)
print(saldo)
print(alder)
print(viktig)

# %% [markdown]
# print() kan også brukes til å skrive ut flere strenger:

# %%
print("Kontoinnehaveren", kontoinnehaver, "har", saldo, "NOK på kontoen", "og er", alder, "år")

# %% [markdown]
# ### Egendefinerte funksjoner
# Ofte er det praktisk å definere egne funksjoner for å løse den oppgaven vi har fått. Det gjøres ved å:
# -  skrive: def. Som betyr at det kommer en funksjonsdefinisjon
# - skrive navnet på funksjonen man vil lage, med parameterlisten i parentes, etterfulgt av kolon.
# - Lage et innrykk i linjen under og skrive hva man vil at funskjonen skal gjøre.Dette kan ta mange linjer.
#
# For eksempel:

# %%
def skrive_kontoinfo_til_skjerm(kunde_navn, kunde_saldo, kunde_alder):
    print("Kontoinnehaveren", kunde_navn, "har", kunde_saldo, "NOK på kontoen", "og er", kunde_alder, "år")

# %% [markdown]
# Nå har vi definert funksjonen. For at det skal se noe må vi kalle funksjonen med de variablene vi vil at den skal ta inn:

# %%
skrive_kontoinfo_til_skjerm(kontoinnehaver,saldo,alder)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 skrive_kontoinfo_til_skjerm(kontoinnehaver,saldo,alder)
#
# NameError: name 'kontoinnehaver' is not defined

# %% [markdown]
# Vi kan også la funksjonen vår returnere en verdi. Man kan returnere en float, en bool, en string eller int. La oss lage en ny versjon av funksjonen skrive_kontoinfo_til_skjerm( , , ). Vi kaller den skrive_kontoinfo( , , ).

# %%
def skrive_kontoinfo(kunde_navn, kunde_saldo, kunde_alder):

# %%
print(skrive_kontoinfo(kontoinnehaver,saldo,alder))

# %% [markdown]
# La oss se på hvordan vi kan skrive et program både med og uten funksjoner:

# %%
# Krisekalkulator: Bruker gir sin alder og programmet oppgir
#hvor lenge det er til han fyller 40

panikk_alder = 50
alder_str = input("Hvor gammel er du? \n")
alder_int = int(alder_str)
panikk_faktor = panikk_alder-alder_int
print("Om", panikk_faktor, "år, fyller du", panikk_alder)

# %% [markdown]
# Oppgave: Lag et program som gjør det samme ved bruk av funksjoner.

# %% [markdown]
# # Datastrukturer
# Ofte er vi interesserte i en mengde data, ikke et enkelt beløp eller stykke tekst. Derfor
# har Python hendige datastrukturer. Et av de nyttigste og mest praktiske eksemplene er
# lister:
# ## Lister
# Man kan definere lister ved å angi elementene:

# %%
kontoinfo_liste = [kontoinnehaver, saldo, alder, viktig]

# %%
print(kontoinfo_liste)

# %% [markdown]
# Man kan få tilgang til elementene i en liste på følgende måte:

# %% [markdown]
# Legg merke til at python begynner å telle på 0.

# %% [markdown]
# En funksjon kan også ta inn en liste som argument.

# %%
def skrive_kontoinfo_med_liste(min_kontoinfo_liste):
     return "Kontoinnehaveren " + min_kontoinfo_liste[0] + " har " + str(min_kontoinfo_liste[1]) + " NOK på kontoen" " og er " + str(kontoinfo_liste[2])+  " år"

# %%
print(skrive_kontoinfo_med_liste(kontoinfo_liste))

# %% [markdown]
# Vi kan også la en funksjon returnere en liste:

# %%
def create_age_list(kontoinfo_liste_1, kontoinfo_liste_2):
    agelist = [0,0]#Vi må lage listen før vi kan endre og returnere den
    agelist[0] = kontoinfo_liste_1[2]
    agelist[1] = kontoinfo_liste_2[2]
    return agelist

# %%
bjerke_konto = ["Lisa Bjerke", 23234.23, 23, False]
vatne_konto  = ["Halvard Vatne", 234234234.23, 69, True]

print(create_age_list(bjerke_konto,vatne_konto))
# Out:
# [23, 69]

# %% [markdown]
# ### Slicing
# For å hente ut deler av en liste kan man bruke en teknik som kalles "slicing". Dersom vi vil ha de tre første elementene fra vatne_konto, gjør vi det slik:

# %% [markdown]
# Vi ser at vi får en liste med alle elementene fra og med new_vatne[0] til OG IKKE MED new_vatne[3].

# %% [markdown]
# Dersom vi er interesser i de to siste elementene i listen kan vi gjøre det på følgende måte:

# %% [markdown]
# Vi ser at vi får en liste med elementene fra og med, eller til, last_vatne[2],

# %% [markdown]
# ### Funksjoner for lister

# %% [markdown]
# Det finnes en mengde funksjoner for lister. Her er noen eksempler:

# %%
example_list =[3,45,67,-5,45,8]
#Vi kan sortere lister med sort()
example_list.sort()
#Vi kan legge til lister med append()
example_list.append(-6)
#Vi kan få plasseringen til et element():
plassering = example_list.index(45)
#Vi kan får lengden til en liste med len()
example_lengde = len(example_list)
#Vi kan kopiere en liste med copy()
new_example=example_list[2:5].copy()

# %% [markdown]
# ## Litt mer om boolske varibler
# boolske variabler har kun to mulige verdier, True eller False. Her er noen eksempler:

# %%
a = 2  > 3
b = 2 < 3
c = 2==3
d =  2==2

# %% [markdown]
# I sammenheng med boolske variabler er det ofte nyttig å bruke logiske operatorer:
# -  Negasjonsoperatoren: not
# -  logisk og: and
# -  logisk eller: or
#
# La oss se på noen eksempler:

# %%
e = not a and  not c

x = 5
y = 6

f = (x*12 == y*10) and (y>x)

# %% [markdown]
# ## if else
# I programmering er det ofte nyttig å gjøre en ting dersom et vilkår er oppfyllt, noe annet dersom det ikke er oppfyllt. I Python bruker gjør man dette på følgende måte:
# ```python
# if(et vilkår er oppfylt):
#     Gjør noe
# else:
#     gjør noe annet
#
# ```
# Dersom man skal utføre noe dersom et vilkår er oppfylt, og dersom det ikke er oppfylt skal man gjøre ingenting skriver man det kanske enkelt slik:
# ```python
# if(et vilkår er oppfylt):
#     Gjør noe
# eventuelt fortsette programmet
#
# ```
# Der vilkåret som skal oppfylles er en boolsk variabel. La oss se hvordan dette kan fungere i praksis.

# %%
a=0
b=1
#if(a>b):
#    print("a er større enn b")
#else:
#    print("a er mindre eller lik b")


if(a<b):
    a= b
else:
    a= 2*a
c = 2
d=1
if(c<d):
    c = d

def konto_beløp(startbeløp,antall_år):
    if(startbeløp < 400000):
        return startbeløp*1.02**antall_år
    else:
        return startbeløp*1.04**antall_år

# %% [markdown]
# La oss bruke dette i et par funksjoner som der vi bruker lister:

# %%
bjerke_konto = ["Lisa Bjerke", 23234.23, 23, False]
vatne_konto  = ["Halvard Vatne", 234234234.23, 69, True]

def rikeste_navn(konto_info_1, konto_info_2):
    if(konto_info_1[1] > konto_info_2[1]):
        return konto_info_1[0]
    else:
        return konto_info_2[0]


def skrive_kontoinfo_med_liste_utvidet(min_kontoinfo_liste):
    temp_string = "Kontoinnehaveren " + min_kontoinfo_liste[0] + " har " + str(min_kontoinfo_liste[1]) + " NOK på kontoen" ", er " + str(min_kontoinfo_liste[2])+  " år"
    if(min_kontoinfo_liste[3]):
        temp_string = temp_string +" og er en viktig kunde."
    else:
        temp_string = temp_string + " og er ikke en viktig kunde."
    return temp_string
#print(rikeste_navn(vatne_konto, bjerke_konto))
#print(rikeste_navn(vatne_konto, bjerke_konto))
#print(skrive_kontoinfo_med_liste_utvidet(vatne_konto))
#print(skrive_kontoinfo_med_liste_utvidet(bjerke_konto))

# %% [markdown]
# ### Oppgave
# Gjør om på programmet som skriver ut panikkalder slik at det skriver ut antall år siden man passerte panikkalderen dersom alderen er over panikkalder.

# %%
#panikk_alder = 50
#alder_str = input("Hvor gammel er du? \n")
#alder_int = int(alder_str)
#panikk_faktor = panikk_alder-alder_int
#print("Om", panikk_faktor, "år, fyller du", panikk_alder)

# %% [markdown]
# ## while-løkker
# Ofte er vi interessert i å kjøre et stykke kode helt til et vilkår er oppfylt. Til det kan vi bruke while løkker. I python gjør vi dette på følgende måte:
# ```python
# while betingelse:
#     gjør noe
# ```
# La oss se hvordan dette fungerer med noen enkle eksempler.

# %%
i = 3
while i<10:
    i = i*(i-1)



def skriv_kontobeholdning(kundenavn, startår ,startbeløp, rente):
    beløp = startbeløp
    år = startår
    while beløp < (2 * startbeløp):
        print(kundenavn, "har", round(beløp,2), "på kontoen i",år)
        år = år + 1
        beløp=beløp*(1+rente)
    print("Det tok", år - startår, "å doble inskuddet")

# %% [markdown]
# while løkker fungerer godt sammen med lister. La oss se på noen eksempler:

# %%
def skriv_kontobeholdning_til_liste(kundenavn, startår ,startbeløp, rente):
    beløp = startbeløp
    år = startår
    beløpliste= []
    while beløp < (2 * startbeløp):
        beløpliste.append(beløp)
        år = år + 1
        beløp=round(beløp*(1+rente),2)
    return beløpliste
beløpliste= skriv_kontobeholdning_til_liste("Harald", 2023 ,234000, 0.09)

# %%
i = 0
#while i < len(beløpliste):
 #   print("I",2023+i, "har Jonas", beløpliste[i], "på kontoen")
   # i = i+1
