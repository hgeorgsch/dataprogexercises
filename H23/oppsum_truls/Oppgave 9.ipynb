# %% [markdown]
# # Oppgave 1: Gjensyn med populasjonsvekst
# ----
#
#
#
#
# Populasjonsveksten antas beskrevet av den logistiske ligningen:
#
# $$
# P(t) = \frac{K}{1+Ae^{-rt}}
# $$
# Her er:
# * $P(t)$: Populasjon ved tiden t
# * $t$ er tiden
# * $r$ er relativ vekstrate, feks 2%
# * $K$ er makskapasiteten til populasjonen
# * $e$ er eulers tall: $e\approx 2,71828$
#
# $A$ er en koeffisient definert ved:
# $$
# A = \frac{K-P_0}{P_0}
# $$
# Hvor $P_0$ er populasjonen ved $t=0$
#
# Dere skal lage et program som:
# -  Beregner hvor lang tid det tar å nå en gitt målpopulasjon.
# -  Lager en liste over populasjonen frem til det tidspunktet.
# -  Lager en graf som viser populasjonen frem til det tidspunktet.
# -  Beregner gjennomsnitspopulasjonen frem til det tidspunktet.
#
#
# Forslag til ekstraoppgaver:
# -  Lag en liste eller et numpy array over hvor lang tid det tar å nå en gitt målpopulasjon med ulik vekstrate r, og plot resultatene.
# -  Lag en liste eller et numpy array over hvor lang tid det tar å nå en gitt målpopulasjon med ulik startpopulasjon $P_0$, og plot resultatene.

# %%
#Din kode her:
