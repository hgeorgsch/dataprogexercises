# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # 7.1
# * Hent data fra ssb og lag dataframet under.
# * Den er laget på tabell 14061: Boligøkonomi. Husholdninger, etter statistikkvariabel, inntektsgruppe og år
# * Den viser andel uten boliglån for ulike inntektskvartiler
# * Plot dataene - Hva forteller den oss?
# ![img/oppg71.png](img/oppg71.png)
